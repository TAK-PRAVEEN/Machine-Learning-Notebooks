# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('mpg')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.drop('name',axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df['horsepower']=df['horsepower'].fillna(df['horsepower'].median())
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
df['origin']=df['origin'].map({"usa":1,"japan":2,"europe":3})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 25.0 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 25.0 KB

# %%
x=df.drop('mpg',axis=1)
y=df['mpg']
x,y
# Out:
# (     cylinders  displacement  horsepower  weight  acceleration  model_year  \
#  0            8         307.0       130.0    3504          12.0          70
#  1            8         350.0       165.0    3693          11.5          70
#  2            8         318.0       150.0    3436          11.0          70
#  3            8         304.0       150.0    3433          12.0          70
#  4            8         302.0       140.0    3449          10.5          70
#  ..         ...           ...         ...     ...           ...         ...
#  393          4         140.0        86.0    2790          15.6          82
#  394          4          97.0        52.0    2130          24.6          82
#  395          4         135.0        84.0    2295          11.6          82
#  396          4         120.0        79.0    2625          18.6          82
#  397          4         119.0        82.0    2720          19.4          82
#
#       origin
#  0         1
#  1         1
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)
x_train.shape,y_train.shape
# Out:
# ((278, 7), (278,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([21.16196121, 27.89684387, 20.45045592, 27.12361164, 24.36117063,
#        15.87763934, 29.93157794, 34.02155729, 17.08992155, 10.56782304,
#        30.53231377, 16.48854992, 22.4061424 , 27.76978226, 36.0209892 ,
#        23.79725872, 10.82747269, 20.27707855,  8.86935273, 32.48801009,
#        25.36507567, 32.75235387, 20.95486868, 24.54530695, 25.77582154,
#        30.20140405, 32.01102103, 31.96692512, 15.25929349, 30.41225966,
#        27.50427715, 10.93370544, 21.42816438, 28.08300976, 25.03368839,
#        13.67199264, 26.67769394,  9.04050101, 32.03270673, 23.97429191,
#        24.18855895, 24.60440771, 21.16368861, 34.53665774, 26.31981331,
#        22.23170907, 21.0865992 , 11.65432984, 27.9398198 , 18.98058597,
#        23.69821181, 26.86564242, 17.04794305, 12.03955477, 28.70876897,
#        24.26227131, 10.20293895, 13.03594704, 29.96910853, 35.35029687,
#        37.01162788, 35.38558158, 18.04991116, 27.90304164, 20.67174751,
# ...

# %%
for i,columns in enumerate(x_train.columns):
  print(f'The coefficient for {columns} is {model.coef_[i]}')
# Out:
# The coefficient for cylinders is -0.31761423027992997
# The coefficient for displacement is 0.02623748259907894
# The coefficient for horsepower is -0.018270764913124644
# The coefficient for weight is -0.007487750398361904
# The coefficient for acceleration is 0.050406734619713886
# The coefficient for model_year is 0.8470951427061371
# The coefficient for origin is 1.5190958387975042

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8348001123742284

# %%
#RIDGE REGRESSION

# %%
from sklearn.linear_model import Ridge
ridge_regression_model=Ridge(alpha=0.1)
ridge_regression_model.fit(x_train,y_train)
for i,column in enumerate(x_train.columns):
  print(f'The coefficient for {column} is {ridge_regression_model.coef_[i]}')
# Out:
# The coefficient for cylinders is -0.31700321010067906
# The coefficient for displacement is 0.02621324975798342
# The coefficient for horsepower is -0.018263252481449534
# The coefficient for weight is -0.00748732605021309
# The coefficient for acceleration is 0.050368969474425776
# The coefficient for model_year is 0.8470062938903167
# The coefficient for origin is 1.5174528285653937

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred) #0.8348001123742284
# Out:
# 0.8348001123742284

# %%
#LASSO REGRESSION

# %%
from sklearn.linear_model import Lasso
lasso_regression_model=Lasso(alpha=0.1)
lasso_regression_model.fit(x_train,y_train)
for i,column in enumerate(x_train.columns):
  print(f"The coefficient for {column} is {lasso_regression_model.coef_[i]}")
# Out:
# The coefficient for cylinders is -0.0
# The coefficient for displacement is 0.017751964528123634
# The coefficient for horsepower is -0.019307657818043437
# The coefficient for weight is -0.007285668218708932
# The coefficient for acceleration is 0.011179016975864573
# The coefficient for model_year is 0.8258205650724195
# The coefficient for origin is 1.1922557769714675

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred) #0.8348001123742284
# Out:
# 0.8348001123742284

# %%
#ELASTIC NET

# %%
from sklearn.linear_model import ElasticNet
elasticnet_regression_model=ElasticNet(alpha=0.1)
elasticnet_regression_model.fit(x_train,y_train)
for i,column in enumerate(x_train.columns):
  print(f"The coefficient for {column} is {elasticnet_regression_model.coef_[i]}")
# Out:
# The coefficient for cylinders is -0.06502074597112191
# The coefficient for displacement is 0.01891840594476452
# The coefficient for horsepower is -0.01802687975834688
# The coefficient for weight is -0.007338549014829311
# The coefficient for acceleration is 0.02647459572161705
# The coefficient for model_year is 0.8261568816701563
# The coefficient for origin is 1.1759869894387145

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8348001123742284

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
vif['features']=df.columns
vif
# Out:
#           vif      features
# 0   53.449934           mpg
# 1  117.191188     cylinders
# 2  101.901839  displacement
# 3   65.410877    horsepower
# 4  172.067800        weight
# 5   69.209218  acceleration
# 6  290.844630    model_year
# 7    8.322385        origin

# %%
df1=df.copy()
df1
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
df1.drop('model_year',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['features']=df1.columns
vif
# Out:
#           vif      features
# 0   20.232621           mpg
# 1  108.235469     cylinders
# 2   92.597731  displacement
# 3   55.953222    horsepower
# 4  149.113990        weight
# 5   52.093023  acceleration
# 6    8.258284        origin

# %%
df1.drop('weight',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['features']=df1.columns
vif
# Out:
#           vif      features
# 0   18.358816           mpg
# 1  106.286975     cylinders
# 2   77.521871  displacement
# 3   43.656711    horsepower
# 4   28.753648  acceleration
# 5    8.190286        origin

# %%
df1.drop('cylinders',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['features']=df1.columns
vif
# Out:
#          vif      features
# 0  17.753559           mpg
# 1  33.642790  displacement
# 2  42.741764    horsepower
# 3  24.344301  acceleration
# 4   8.088967        origin

# %%
df1.drop('horsepower',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['features']=df1.columns
vif
# Out:
#          vif      features
# 0  16.940389           mpg
# 1   3.912248  displacement
# 2  23.950582  acceleration
# 3   6.710190        origin

# %%
df1.drop('acceleration',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['features']=df1.columns
vif
# Out:
#         vif      features
# 0  7.231419           mpg
# 1  2.050251  displacement
# 2  6.290270        origin

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
rfe=RFE(estimator=lr,n_features_to_select=5)
rfe.fit(df,y)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=5)

# %%
rfe.support_
# Out:
# array([ True,  True, False,  True, False,  True,  True, False])

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')
